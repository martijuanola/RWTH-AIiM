# %% [markdown]
# # Exercise 9: Template-Based Chord Recognition

# %% [markdown]
# ## Imports

# %%
import pathlib

# %% [markdown]
# ## Constants

# %%
current_dir = pathlib.Path.cwd()

# Dataset
data_path = current_dir.joinpath("data")

# File extensions
AUDIO_EXTENSION = ".wav"

# File paths
audio_file_paths = list(data_path.glob(f"*{AUDIO_EXTENSION}"))
assert len(audio_file_paths) == 1, f"Mix file with extension {AUDIO_EXTENSION} not found!"
audio_file_path = audio_file_paths[0]
print(f"Audio file path: {audio_file_path}")
# Out:
# Audio file path: /Users/martijuanola/git_repositories/RWTH-AIiM/exercices/e9/data/exercise_7ths.wav

# %% [markdown]
# ## Tutorial [from  [Audiolabs Erlangen Website](https://www.audiolabs-erlangen.de/resources/MIR/FMP/C5/C5S2_ChordRec_Templates.html)]

# %%
# TODO: compy tutorial and understand

# %% [markdown]
# ## Exercise 1 [Extension to Seventh Chords, 5 points]

# %%
# TODO: ...
